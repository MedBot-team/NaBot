# %%
import pandas as pd
import os

res1 = pd.read_json(os.path.join(os.getcwd(), os.pardir, '1', 'story_report.json')
                    , orient ='index')
res2 = pd.read_json(os.path.join(os.getcwd(), os.pardir, '2', 'story_report.json')
                    , orient ='index')

# %%
res1
# Out:
#                               precision    recall  f1-score  support  \
# [ketamine](drug)               1.000000  1.000000  1.000000      2.0
# [skin biopsy](lab)             1.000000  1.000000  1.000000      1.0
# [panic disorder test](lab)     1.000000  1.000000  1.000000      1.0
# [rash evaluation](lab)         1.000000  1.000000  1.000000      2.0
# drug_retrieve                  0.666667  0.857143  0.750000      7.0
# inform_drug                    1.000000  0.500000  0.666667      2.0
# inform_lab                     0.000000  0.000000  0.000000      1.0
# [letrozole](drug)              1.000000  1.000000  1.000000      1.0
# prepare-lab                    0.000000  0.000000  0.000000      1.0
# during_lab                     1.000000  1.000000  1.000000      2.0
# interaction_drug               1.000000  1.000000  1.000000      1.0
# [estradiol](drug)              1.000000  1.000000  1.000000      1.0
# [fosamax](drug)                1.000000  1.000000  1.000000      1.0
# [laparoscopy](lab)             0.500000  1.000000  0.666667      1.0
# [glucose in urine test](lab)   1.000000  1.000000  1.000000      1.0
# greet                          0.500000  1.000000  0.666667      1.0
# usage_lab                      0.500000  0.333333  0.400000      3.0
# request_lab                    0.666667  1.000000  0.800000      2.0
# dosage_drug                    1.000000  1.000000  1.000000      1.0
# need_lab                       0.000000  0.000000  0.000000      1.0
# labs_form                      1.000000  0.750000  0.857143      4.0
# [colposcopy](lab)              0.500000  1.000000  0.666667      1.0
# [clodan](drug)                 1.000000  1.000000  1.000000      1.0
# any_detail_lab                 1.000000  1.000000  1.000000      1.0
# None                           0.000000  0.000000  0.000000      4.0
# [kalbitor](drug)               1.000000  1.000000  1.000000      1.0
# result_lab                     1.000000  1.000000  1.000000      1.0
# [advil](drug)                  1.000000  1.000000  1.000000      1.0
# [pregnancy test](lab)          1.000000  1.000000  1.000000      1.0
# [acetaminophen](drug)          0.500000  1.000000  0.666667      1.0
# [drug testing](lab)            0.000000  0.000000  0.000000      2.0
# warning_drug                   0.000000  0.000000  0.000000      1.0
# usage_drug                     0.000000  0.000000  0.000000      2.0
# utter_greet                    1.000000  1.000000  1.000000      1.0
# detail_lab                     0.000000  0.000000  0.000000      1.0
# [troponin test](lab)           1.000000  1.000000  1.000000      2.0
# lab_retrieve                   0.833333  0.909091  0.869565     11.0
# avoid_drug                     1.000000  1.000000  1.000000      1.0
# request_drug                   0.750000  1.000000  0.857143      3.0
# risk_lab                       0.000000  0.000000  0.000000      1.0
# sideeffects_drug               0.333333  1.000000  0.500000      1.0
# action_listen                  1.000000  0.740741  0.851064     27.0
# drugs_form                     1.000000  1.000000  1.000000      6.0
# micro avg                      0.852632  0.750000  0.798030    108.0
# macro avg                      0.691860  0.746286  0.702750    108.0
# weighted avg                   0.780093  0.750000  0.750870    108.0
# conversation_accuracy               NaN       NaN       NaN      NaN
#
#                               accuracy  correct  with_warnings  total
# [ketamine](drug)                   NaN      NaN            NaN    NaN
# [skin biopsy](lab)                 NaN      NaN            NaN    NaN
# [panic disorder test](lab)         NaN      NaN            NaN    NaN
# [rash evaluation](lab)             NaN      NaN            NaN    NaN
# drug_retrieve                      NaN      NaN            NaN    NaN
# inform_drug                        NaN      NaN            NaN    NaN
# inform_lab                         NaN      NaN            NaN    NaN
# [letrozole](drug)                  NaN      NaN            NaN    NaN
# prepare-lab                        NaN      NaN            NaN    NaN
# during_lab                         NaN      NaN            NaN    NaN
# interaction_drug                   NaN      NaN            NaN    NaN
# [estradiol](drug)                  NaN      NaN            NaN    NaN
# [fosamax](drug)                    NaN      NaN            NaN    NaN
# [laparoscopy](lab)                 NaN      NaN            NaN    NaN
# [glucose in urine test](lab)       NaN      NaN            NaN    NaN
# greet                              NaN      NaN            NaN    NaN
# usage_lab                          NaN      NaN            NaN    NaN
# request_lab                        NaN      NaN            NaN    NaN
# dosage_drug                        NaN      NaN            NaN    NaN
# need_lab                           NaN      NaN            NaN    NaN
# labs_form                          NaN      NaN            NaN    NaN
# [colposcopy](lab)                  NaN      NaN            NaN    NaN
# [clodan](drug)                     NaN      NaN            NaN    NaN
# any_detail_lab                     NaN      NaN            NaN    NaN
# None                               NaN      NaN            NaN    NaN
# [kalbitor](drug)                   NaN      NaN            NaN    NaN
# result_lab                         NaN      NaN            NaN    NaN
# [advil](drug)                      NaN      NaN            NaN    NaN
# [pregnancy test](lab)              NaN      NaN            NaN    NaN
# [acetaminophen](drug)              NaN      NaN            NaN    NaN
# [drug testing](lab)                NaN      NaN            NaN    NaN
# warning_drug                       NaN      NaN            NaN    NaN
# usage_drug                         NaN      NaN            NaN    NaN
# utter_greet                        NaN      NaN            NaN    NaN
# detail_lab                         NaN      NaN            NaN    NaN
# [troponin test](lab)               NaN      NaN            NaN    NaN
# lab_retrieve                       NaN      NaN            NaN    NaN
# avoid_drug                         NaN      NaN            NaN    NaN
# request_drug                       NaN      NaN            NaN    NaN
# risk_lab                           NaN      NaN            NaN    NaN
# sideeffects_drug                   NaN      NaN            NaN    NaN
# action_listen                      NaN      NaN            NaN    NaN
# drugs_form                         NaN      NaN            NaN    NaN
# micro avg                          NaN      NaN            NaN    NaN
# macro avg                          NaN      NaN            NaN    NaN
# weighted avg                       NaN      NaN            NaN    NaN
# conversation_accuracy              0.0      0.0            0.0    6.0

# %%
overall_indices = ['micro avg', 'macro avg', 'weighted avg']
intent_list = ['affirm',
            'any_detail_lab',
            'avoid_drug',
            'bot_challenge',
            'deny',
            'detail_lab',
            'dosage_drug',
            'during_lab',
            'goodbye',
            'greet',
            'inform_drug',
            'inform_lab',
            'interaction_drug',
            'mood_great',
            'mood_unhappy',
            'need_lab',
            'prepare_lab',
            'request_drug',
            'request_lab',
            'result_lab',
            'risk_lab',
            'sideeffects_drug',
            'usage_drug',
            'usage_lab',
            'warnings_drug',
            ]
intent_indices = [index for index in res1.index if index in intent_list]
action_indices = ['drug_retrieve','lab_retrieve','action_listen', 'utter_greet']
entity_indices = []
for index in res1.index:
    if index not in (overall_indices + intent_indices + action_indices):
        entity_indices.append(index)

# %%
import matplotlib.pyplot as plt
import numpy as np
w = 0.4
fig, ax = plt.subplots(figsize=(15,8))
X_axis = np.arange(len(action_indices))
ax.bar(X_axis-w/2, res1.loc[action_indices, 'f1-score'], width=w , label='config 1')
ax.bar(X_axis+w/2, res2.loc[action_indices, 'f1-score'], width=w, label='config 2')
ax.set_xticks(X_axis)
ax.set_xticklabels(action_indices)
ax.legend()
ax.set_title('f1-score of actions')
plt.show()

# %%
w = 0.4
fig, ax = plt.subplots(figsize=(15,8))
X_axis = np.arange(len(intent_indices))
ax.bar(X_axis-w/2, res1.loc[intent_indices, 'f1-score'], width=w , label='config 1')
ax.bar(X_axis+w/2, res2.loc[intent_indices, 'f1-score'], width=w, label='config 2')
ax.set_xticks(X_axis)
ax.set_xticklabels(intent_indices, rotation=45, ha='right')
ax.legend()
ax.set_title('f1-score of intents')
plt.show()

# %%
w = 0.4
fig, ax = plt.subplots(figsize=(15,8))
X_axis = np.arange(len(entity_indices))
ax.bar(X_axis-w/2, res1.loc[entity_indices, 'f1-score'], width=w , label='config 1')
ax.bar(X_axis+w/2, res2.loc[entity_indices, 'f1-score'], width=w, label='config 2')
ax.set_xticks(X_axis)
ax.set_xticklabels(entity_indices, rotation=45, ha='right')
ax.legend()
ax.set_title('f1-score of entities')
plt.show()

# %%
w = 0.4
fig, ax = plt.subplots(figsize=(15,8))
X_axis = np.arange(len(overall_indices))
ax.bar(X_axis-w/2, res1.loc[overall_indices, 'f1-score'], width=w , label='config 1')
ax.bar(X_axis+w/2, res2.loc[overall_indices, 'f1-score'], width=w, label='config 2')
ax.set_xticks(X_axis)
ax.set_xticklabels(overall_indices, rotation=45, ha='right')
ax.legend()
ax.set_title('overall f1-score')
plt.show()

# %%
w = 0.4
fig, ax = plt.subplots(figsize=(15,8))
X_axis = np.arange(len(entity_indices))
ax.bar(X_axis-w/2, res1.loc[entity_indices, 'support'], width=w , label='config 1')
ax.bar(X_axis+w/2, res2.loc[entity_indices, 'support'], width=w, label='config 2')
ax.set_xticks(X_axis)
ax.set_xticklabels(entity_indices, rotation=45, ha='right')
ax.legend()
ax.set_title('support of entities')
plt.show()

# %%
w = 0.4
fig, ax = plt.subplots(figsize=(15,8))
X_axis = np.arange(len(intent_indices))
ax.bar(X_axis-w/2, res1.loc[intent_indices, 'support'], width=w , label='config 1')
ax.bar(X_axis+w/2, res2.loc[intent_indices, 'support'], width=w, label='config 2')
ax.set_xticks(X_axis)
ax.set_xticklabels(intent_indices, rotation=45, ha='right')
ax.legend()
ax.set_title('support of intents')
plt.show()

# %%
w = 0.4
fig, ax = plt.subplots(figsize=(15,8))
X_axis = np.arange(len(action_indices))
ax.bar(X_axis-w/2, res1.loc[action_indices, 'support'], width=w , label='config 1')
ax.bar(X_axis+w/2, res2.loc[action_indices, 'support'], width=w, label='config 2')
ax.set_xticks(X_axis)
ax.set_xticklabels(action_indices, rotation=45, ha='right')
ax.legend()
ax.set_title('support of intents')
plt.show()
