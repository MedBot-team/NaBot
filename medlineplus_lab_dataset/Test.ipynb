# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
cd /content/gdrive/MyDrive/crawl_git_1/chatbot/medlineplus_lab_dataset/urls
# Out:
# /content/gdrive/MyDrive/crawl_git_1/chatbot/medlineplus_lab_dataset/urls

# %%
# !ls
# Out:
# medlineplus_lab_urls.txt  question_list.txt
# question_list_regex.txt   url_archives

# %%
file1 = open('question_list.txt', 'r')
Lines = file1.readlines()

# %%
# list(Lines)
import pandas as pd
df = pd.DataFrame({"question": list(Lines)})

# %%
df.head(3)
# Out:
#                                             question
# 0  are there any risks to a complement blood test?\n
# 1           are there any risks to a d-dimer test?\n
# 2            are there any risks to a dental exam?\n
